# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Read our data to a Dataframe
final_df = pd.read_csv('NBA_Hollinger_Data.csv')
mvp_df = pd.read_csv('NBA_MVP_clean_data.csv')

# %% [markdown]
# ### Visualize Hollinger theory

# %%
plt.figure(figsize=(35,20))
final_df['ht'].value_counts().plot(kind='pie',labels=None,autopct='%1.1f%%',textprops= {'fontsize':20})
plt.legend(fontsize=12,loc="upper right",labels=final_df['ht'])

# %% [markdown]
# ### In this pie chart we can see the precentge of players in our dataset for each category by Hollinger's theory.

# %% [markdown]
# ### Visualize MVP

# %%
#Combine the 2 dataframes into 1 DataFrame
top_per = final_df.loc[final_df.groupby('Year')['PER'].idxmax()]
top_per = top_per.sort_values(by='Year',ascending=False)

top_per.insert(0,'MVP_This_Year',mvp_df['Player'].tolist())
top_per.reset_index()
top_per['Player'] = top_per['Player'].str.replace('*', '')
match = pd.get_dummies(top_per['Player']==top_per['MVP_This_Year'], drop_first=True)
top_per.insert(0,'We_Have_A_Match',match)
top_per.head()
# Out:
#       We_Have_A_Match          MVP_This_Year  Year                 Player Pos  \
# 211                 1           Nikola Jokić  2021           Nikola Jokić   C
# 446                 1  Giannis Antetokounmpo  2020  Giannis Antetokounmpo  PF
# 855                 1  Giannis Antetokounmpo  2019  Giannis Antetokounmpo  PF
# 1356                0           James Harden  2018          Anthony Davis  PF
# 2062                1      Russell Westbrook  2017      Russell Westbrook  PG
#
#        Age   Tm     G    GS      MP  ...    DRB    TRB    AST    STL    BLK  \
# 211   25.0  DEN  72.0  72.0  2488.0  ...  575.0  780.0  599.0   95.0   48.0
# 446   25.0  MIL  63.0  63.0  1917.0  ...  716.0  856.0  354.0   61.0   66.0
# 855   24.0  MIL  72.0  72.0  2358.0  ...  739.0  898.0  424.0   92.0  110.0
# 1356  24.0  NOP  75.0  75.0  2727.0  ...  645.0  832.0  174.0  115.0  193.0
# 2062  28.0  OKC  81.0  81.0  2802.0  ...  727.0  864.0  840.0  132.0   31.0
#
#         TOV     PF     PTS    PER                     ht
# 211   222.0  192.0  1898.0  36.03  All-time great season
# 446   230.0  195.0  1857.0  38.71  All-time great season
# 855   268.0  232.0  1994.0  36.62  All-time great season
# 1356  162.0  159.0  2110.0  32.78  Runaway MVP candidate
# 2062  438.0  190.0  2558.0  33.78  Runaway MVP candidate
#
# [5 rows x 34 columns]

# %% [markdown]
# ### We will examine the relationship between the player with the highest PER and the MVP of that season

# %%
sns.scatterplot(data=top_per, y="Year", x="We_Have_A_Match")
# Out:
# <AxesSubplot:xlabel='We_Have_A_Match', ylabel='Year'>

# %% [markdown]
# ### We notice that as we go up in years the connection between the PER and the MVP is stronger

# %% [markdown]
# ### We will check what percentage of MVP players have the highest PER of their season in the last 30 years

# %%
plt.figure(figsize=(10,10))
plt.pie(x=top_per['We_Have_A_Match'].value_counts(),labels=None,autopct='%1.1f%%',textprops= {'fontsize':20})
plt.legend(fontsize=14,loc="upper right",labels=['The MVP does not have the highest PER','The MVP does have the highest PER'])

# %% [markdown]
# ### Visualize Final Dataset

# %% [markdown]
# ### We can visualize the correlation between PER to other stats using a heatmap
# ### We will use that information to see which stats are most relevant for our model

# %%
plt.figure(figsize=(20,10))
c= final_df.corr()
sns.heatmap(c,cmap='BrBG',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### We will take the data that most influences the PER and show it's correlation with the PER element

# %%
#We want to see a distibution of some of our data to choose our scalar
sns.pairplot(final_df[['PER','FG','FGA','2P','FT','FTA','PTS']], kind='kde')
